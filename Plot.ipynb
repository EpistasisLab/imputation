# %%
import seaborn as sns
import pickle as pkl
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def plot(name, patients):
    for p in patients:
        scores = pkl.load(open('./output/sweeps/' + name + '_' + str(p) + '.p', 'rb'))
        print(scores)
        scores.pop('NuclearMin')
        df = pd.DataFrame.from_dict(scores)

        plt.figure(figsize=(10,10))
        g = sns.boxplot(df)
        g.set_title(name + ' ' + str(p))

# %%
name = 'completeCasesBoxCox'
#patients = [100, 200, 400, 800, 1600, 3200, 6400, 10000]
patients = [10000]
plot(name, patients)
# Out:
# {'knn_30': [0.21196722668434367], 'svd_16': [0.58160924550162008], 'svd_24': [0.29085836701593604], 'knn_15': [0.2204622490839859], 'simple_mean': [0.22435656688275207], 'svd_4': [0.3164876874172754], 'NuclearMin': [], 'svd_8': [0.49414917972142802], 'simple_median': [0.22562406590468792], 'knn_3': [0.26390534403320315], 'knn_1': [0.35077549050199514], 'si': [0.19492131335991053], 'MatrixFactor': [0.38530428227562064], 'MICE': [0.19431116997250758], 'knn_9': [0.22917230642245559]}

# %%
name = 'completeCasesBoxCox'
plot(name, patients)

# %%
name = 'simulation'
plot(name, patients)
